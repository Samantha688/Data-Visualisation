# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
df = pd.read_csv('/Users/samanthalee/Desktop/museum_visitors.csv', index_col = 'Date', parse_dates=True)
df.tail(5)
# Line plot showing the number of visitors to Avila Adobe over time
sns.lineplot(data= df['Avila Adobe'], label="Avila")
# All musuem lines shown 
sns.lineplot(data=df)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Avila Adobe'>
